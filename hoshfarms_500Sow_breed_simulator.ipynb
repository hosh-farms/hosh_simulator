# %% [markdown]
# <a href="https://colab.research.google.com/github/hosh-farms/hosh_simulator/blob/main/hoshfarms_500Sow_breed_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pandas as pd

# --- Farm simulation function ---
def farm_simulator(
    total_sows=30,
    piglets_per_cycle=8,
    sow_mortality=0.033,
    piglet_mortality=0.03,
    sow_feed_price=32,
    sow_feed_intake=2.8,
    grower_feed_price=28,
    fcr=3.2,
    final_weight=105,
    sale_price=180,
    management_fee=50000,
    management_commission=0.05,
    supervisor_salary=25000,
    worker_salary=18000,
    n_workers=2,
    shed_cost=1_000_000,
    shed_life_years=10,
    sow_cost=1_050_000,
    sow_life_years=4,
    loan_amount=0,
    interest_rate=0.1,
    loan_tenure_years=5,
    moratorium_months=0,
    medicine_cost=10000,
    electricity_cost=5000,
    land_lease=10000,
    months=60
):
    current_sows = total_sows
    monthly_data = []

    # Depreciation
    shed_dep = shed_cost / (shed_life_years * 12)
    sow_dep_total = sow_cost / (sow_life_years * 12)

    # Loan EMI calculation
    total_months = loan_tenure_years * 12
    monthly_rate = interest_rate / 12
    emi = 0
    if loan_amount > 0 and total_months > 0:
        emi = loan_amount * monthly_rate * (1 + monthly_rate)**total_months / ((1 + monthly_rate)**total_months - 1)
    loan_balance = loan_amount

    # --- Dynamic sow mating calculation ---
    gestation_months = 114 / 30       # 3.8 months
    lactation_months = 40 / 30        # 1.33 months
    dry_months = 10 / 30               # 0.33 months
    cycle_length = gestation_months + lactation_months + dry_months  # ~5.46 months
    sows_to_mate_per_month = total_sows / cycle_length

    batches = []

    for month in range(1, months + 1):
        sow_feed_cost = current_sows * sow_feed_intake * 30 * sow_feed_price
        staff_cost = supervisor_salary + n_workers * worker_salary
        mgmt_fixed = management_fee

        # Mate sows dynamically
        sows_to_mate = min(round(sows_to_mate_per_month), round(current_sows))
        if sows_to_mate > 0:
            farrow_month = month + int(gestation_months)
            wean_month = farrow_month + int(lactation_months)
            grower_start_month = wean_month
            grower_end_month = grower_start_month + 6
            piglets = sows_to_mate * piglets_per_cycle * (1 - piglet_mortality)
            batches.append({
                'farrow_month': farrow_month,
                'wean_month': wean_month,
                'grower_start_month': grower_start_month,
                'grower_end_month': grower_end_month,
                'piglets': piglets
            })

        # Monthly counters
        piglets_with_sow = 0
        growers = 0
        sold_pigs = 0
        revenue = 0
        grower_feed_cost = 0

        for batch in batches:
            if batch['farrow_month'] <= month < batch['wean_month']:
                piglets_with_sow += batch['piglets']
            if batch['grower_start_month'] <= month < batch['grower_end_month']:
                growers += batch['piglets']
                grower_feed_cost += batch['piglets'] * fcr * final_weight / 6 * grower_feed_price
            if batch['grower_end_month'] == month:
                pigs_sold = batch['piglets'] * (1 - 0.03)
                revenue += pigs_sold * final_weight * sale_price
                sold_pigs += pigs_sold

        mgmt_comm_cost = revenue * management_commission
        other_fixed = medicine_cost + electricity_cost + land_lease
        total_operating_cost = sow_feed_cost + grower_feed_cost + staff_cost + mgmt_fixed + mgmt_comm_cost + other_fixed
        dep = shed_dep + sow_dep_total

        # Loan EMI
        if month <= moratorium_months:
            loan_payment = loan_balance * monthly_rate
        elif month <= total_months:
            interest = loan_balance * monthly_rate
            principal = emi - interest
            loan_balance -= principal
            loan_payment = emi
        else:
            loan_payment = 0

        monthly_data.append({
            'Month': month,
            'Piglets_Born_Alive': int(piglets_with_sow),
            'Growers': int(growers),
            'Sold_Pigs': int(sold_pigs),
            'Revenue': int(revenue),
            'Sow_Feed_Cost': int(sow_feed_cost),
            'Grower_Feed_Cost': int(grower_feed_cost),
            'Staff_Cost': int(staff_cost),
            'Mgmt_Fee': int(mgmt_fixed),
            'Mgmt_Comm': int(mgmt_comm_cost),
            'Other_Fixed_Costs': int(other_fixed),
            'Total_Operating_Cost': int(total_operating_cost),
            'Depreciation': int(dep),
            'Loan_EMI': int(loan_payment)
        })

        current_sows -= current_sows * sow_mortality / 12

    df_month = pd.DataFrame(monthly_data)
    df_month['Year'] = ((df_month['Month'] - 1) // 12) + 1

    cols_to_sum = ['Revenue','Sow_Feed_Cost','Grower_Feed_Cost','Staff_Cost','Mgmt_Fee','Mgmt_Comm',
                   'Other_Fixed_Costs','Total_Operating_Cost','Depreciation','Loan_EMI',
                   'Piglets_Born_Alive','Growers','Sold_Pigs']
    df_year = df_month.groupby('Year')[cols_to_sum].sum()
    df_year.index = [f'Year {i}' for i in df_year.index]
    df_year['Cash_Profit'] = df_year['Revenue'] - df_year['Total_Operating_Cost']
    df_year['Profit_After_Dep_Loan'] = df_year['Cash_Profit'] - df_year['Depreciation'] - df_year['Loan_EMI']

    return df_month, df_year

# --- Streamlit App ---
st.title("30 Sow Farm Simulator (Dynamic Farrowings)")

st.sidebar.header("Farm Parameters")
# Sliders
total_sows = st.sidebar.slider("Total Sows", 10, 500, 30)
piglets_per_cycle = st.sidebar.slider("Piglets per Cycle", 4, 20, 8)
sow_mortality = st.sidebar.slider("Sow Mortality %", 0.0, 0.1, 0.033)
piglet_mortality = st.sidebar.slider("Piglet Mortality %", 0.0, 0.3, 0.03)
sow_feed_price = st.sidebar.slider("Sow Feed Price (₹/kg)", 4, 100, 32)
sow_feed_intake = st.sidebar.slider("Sow Feed Intake (kg/day)", 1.0, 7.0, 2.8)
grower_feed_price = st.sidebar.slider("Grower Feed Price (₹/kg)", 10, 100, 28)
fcr = st.sidebar.slider("FCR", 2.5, 4.0, 3.2, 0.01)
final_weight = st.sidebar.slider("Final Market Weight (kg)", 20, 200, 105)
sale_price = st.sidebar.slider("Sale Price per kg (₹)", 100, 600, 180)
management_fee = st.sidebar.slider("Management Fee (₹/month)", 0, 500000, 50000)
management_commission = st.sidebar.slider("Management Commission %", 0.0, 0.2, 0.05)
supervisor_salary = st.sidebar.slider("Supervisor Salary (₹/month)", 10000, 100000, 25000)
worker_salary = st.sidebar.slider("Worker Salary (₹/month)", 10000, 50000, 18000)
n_workers = st.sidebar.slider("Number of Workers", 0, 20, 2)
shed_cost = st.sidebar.slider("Shed Construction Cost (₹)", 100000, 10000000, 1_000_000)
shed_life_years = st.sidebar.slider("Shed Life (Years)", 1, 20, 10)
sow_cost = st.sidebar.slider("Sow Purchase Cost (₹)", 100000, 10000000, 1_050_000)
sow_life_years = st.sidebar.slider("Sow Life (Years)", 1, 10, 4)
loan_amount = st.sidebar.slider("Loan Amount (₹)", 0, 50000000, 0)
interest_rate = st.sidebar.slider("Loan Interest Rate", 0.0, 0.6, 0.1)
loan_tenure_years = st.sidebar.slider("Loan Tenure (Years)", 1, 10, 5)
moratorium_months = st.sidebar.slider("Loan Moratorium Months", 0, 24, 0)
medicine_cost = st.sidebar.slider("Monthly Medicine Cost (₹)", 0, 100000, 10000)
electricity_cost = st.sidebar.slider("Monthly Electricity Cost (₹)", 0, 100000, 5000)
land_lease = st.sidebar.slider("Monthly Land Lease (₹)", 0, 100000, 10000)
months = st.sidebar.slider("Months to Simulate", 12, 120, 60)

# Run simulation
df_month, df_year = farm_simulator(
    total_sows, piglets_per_cycle, sow_mortality, piglet_mortality, sow_feed_price,
    sow_feed_intake, grower_feed_price, fcr, final_weight, sale_price, management_fee,
    management_commission, supervisor_salary, worker_salary, n_workers,
    shed_cost, shed_life_years, sow_cost, sow_life_years, loan_amount, interest_rate,
    loan_tenure_years, moratorium_months, medicine_cost, electricity_cost, land_lease, months
)

st.subheader("Monthly Table")
st.dataframe(df_month)

st.subheader("Yearly Summary")
st.dataframe(df_year)
# Out:
# 2025-08-28 23:45:31.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-28 23:45:31.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
